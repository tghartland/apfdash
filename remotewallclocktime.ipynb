# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline
pd.set_option('display.max_rows',15)

from pandas import *
from pandas.io.parsers import read_csv

# %%
df = read_csv('c7140593-a64c-4e8e-ba9f-96ef7390a17f.csv', index_col=False)

# %%
fig, ax = plt.subplots(figsize=(9, 6))
df.plot.scatter(ax=ax, x='duration', y='RemoteWallClockTime')
#bnl.hist(ax=ax, bins=bins, label=['bnl'], alpha=0.5)
#ax.set(title='Distribution of write duration', xlabel='Duration (s)', ylabel='Count')
#ax.legend().set_visible(True)

# %%
df
# Out:
#       duration  RemoteWallClockTime
# 0          457                322.0
# 1         1437                185.0
# 2          724                553.0
# 3          363                242.0
# 4         1703               1459.0
# 5          663                424.0
# 6         1376                184.0
# ...        ...                  ...
# 9993       333                303.0
# 9994       333                303.0
# 9995       312                249.0
# 9996       332                302.0
# 9997       346                181.0
# 9998       935                794.0
# 9999       935                794.0
#
# [10000 rows x 2 columns]
